# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# Define the problem you are finding answers for from the data given:
#
# Analyse participation rates across states to determine the appropriate allocation of resources to improve SAT/ACT participation across states.

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
act2017_score = pd.read_csv('../data/act_2017.csv')
sat2017_score = pd.read_csv('../data/sat_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
act_first_ten = act2017_score.head(10)
act_first_ten
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
sat_first_ten = sat2017_score.head(10)
sat_first_ten
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %%
act2017_score.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
sat2017_score.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer: The .describe() shows descriptive statistics for each column in the two dataframes (laying out the subject scores in each state and each states rate of participation in 2017 and 2018) which are the mean, standard deviation, minimum and maximum values, as well as Q1, median, and Q3 percentile values. The data does look complete.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer: Based on the information below, the mininum possible value can be derived in the 'min' row for each test subjects of 16.3, 18, 18,1 and 18.2 respectively for English, Math, Reading and Science of the ACT test. The same applies for the maximum possible value in the 'max' row.

# %%
act2017_score.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# Answer: Based on the information below, the mininum possible value can be derived in the 'min' row for each test subjects of 482 and 468 respectively for Reading/Writing and Math of the SAT test. The same applies for the maximum possible value in the 'max' row.

# %%
sat2017_score.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %% [markdown]
# There is however some outliers as seen form above which should be cleaned. Firstly, there is an additional row of the national average in the ACT 2017 table, so the data has 51 rows corresponding to the 50 states and the District of Columbia. There are no values are missing in any of the data columns for either dataframe.
#
# ACT average scores typically is around 20 for each section. There does not seem to have any bad data. The participation percentages need to be converted to numerical format, currently it is an object.

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
act2017_score.replace(to_replace=['20.2x',2.3], value = [20.2,23.2], inplace=True)
sat2017_score.replace(to_replace=52,value=524,inplace=True)

# %% [markdown]
# There is a '20.2x' for Wyoming which would affect the rest of the data to be strings.

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
act2017_score.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null object
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %% [markdown]
# Float or Objects for each feature in ACT.

# %%
sat2017_score.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %% [markdown]
# Float or Integers for each feature in SAT.

# %%
act2017_score.columns
# Out:
# Index(['State', 'Participation', 'English', 'Math', 'Reading', 'Science',
#        'Composite'],
#       dtype='object')

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:
# In ACT 2017, the National scores has been included and should be later removed to compare the 50 individual states only across.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
def perc_to_int(df,col):
    def perc_data(perc):
        return int(perc.replace("%",""))
    df[col]=df[col].apply(perc_data)
    return df

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
perc_to_int(sat2017_score, 'Participation')
# Out:
#                    State  Participation  Evidence-Based Reading and Writing  \
# 0                Alabama              5                                 593
# 1                 Alaska             38                                 547
# 2                Arizona             30                                 563
# 3               Arkansas              3                                 614
# 4             California             53                                 531
# 5               Colorado             11                                 606
# 6            Connecticut            100                                 530
# 7               Delaware            100                                 503
# 8   District of Columbia            100                                 482
# 9                Florida             83                                 520
# 10               Georgia             61                                 535
# ...

# %%
sat2017_score.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null int64
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(4), object(1)
# memory usage: 2.1+ KB

# %%
perc_to_int(act2017_score, 'Participation')
# Out:
#                    State  Participation  English  Math  Reading  Science  \
# 0               National             60     20.3  20.7     21.4     21.0
# 1                Alabama            100     18.9  18.4     19.7     19.4
# 2                 Alaska             65     18.7  19.8     20.4     19.9
# 3                Arizona             62     18.6  19.8     20.1     19.8
# 4               Arkansas            100     18.9  19.0     19.7     19.5
# 5             California             31     22.5  22.7     23.1     22.2
# 6               Colorado            100     20.1  20.3     21.2     20.9
# 7            Connecticut             31     25.5  24.6     25.6     24.6
# 8               Delaware             18     24.1  23.4     24.8     23.6
# 9   District of Columbia             32     24.4  23.5     24.9     23.5
# 10               Florida             73     19.0  19.4     21.0     19.4
# 11               Georgia             55     21.0  20.9     22.0     21.3
# ...

# %%
act2017_score.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null int64
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 3.0+ KB

# %%
def obj_to_float(df,col):
    def perc_data(perc):
        return float(perc)
    df[col]=df[col].apply(perc_data)
    return df

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
obj_to_float(act2017_score, 'Composite')
# Out:
#                    State  Participation  English  Math  Reading  Science  \
# 0               National             60     20.3  20.7     21.4     21.0
# 1                Alabama            100     18.9  18.4     19.7     19.4
# 2                 Alaska             65     18.7  19.8     20.4     19.9
# 3                Arizona             62     18.6  19.8     20.1     19.8
# 4               Arkansas            100     18.9  19.0     19.7     19.5
# 5             California             31     22.5  22.7     23.1     22.2
# 6               Colorado            100     20.1  20.3     21.2     20.9
# 7            Connecticut             31     25.5  24.6     25.6     24.6
# 8               Delaware             18     24.1  23.4     24.8     23.6
# 9   District of Columbia             32     24.4  23.5     24.9     23.5
# 10               Florida             73     19.0  19.4     21.0     19.4
# 11               Georgia             55     21.0  20.9     22.0     21.3
# ...

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
act2017_score.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null int64
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 3.0+ KB

# %%
sat2017_score.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null int64
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(4), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
act2017_score.columns
# Out:
# Index(['State', 'Participation', 'English', 'Math', 'Reading', 'Science',
#        'Composite'],
#       dtype='object')

# %%
act2017_score.rename(columns={"State": "state","Participation": "act2017_participation", "English": "act2017_eng", "Math":"act2017_math", "Reading":"act2017_reading","Science":"act2017_science","Composite":"act2017_composite"}, inplace=True)
act2017_score.columns
# Out:
# Index(['state', 'act2017_participation', 'act2017_eng', 'act2017_math',
#        'act2017_reading', 'act2017_science', 'act2017_composite'],
#       dtype='object')

# %%
sat2017_score.rename(columns={"State":"state","Participation": "sat2017_participation", "Evidence-Based Reading and Writing":"sat2017_erw","Math":"sat2017_math","Total":"sat2017_total"}, inplace=True)
sat2017_score.columns
# Out:
# Index(['state', 'sat2017_participation', 'sat2017_erw', 'sat2017_math',
#        'sat2017_total'],
#       dtype='object')

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# | Column Name           | Dataset (Test & Year)            | Type  | Description                                                  |
# | --------------------- | -------------------------------- | ----- | ------------------------------------------------------------ |
# | state                 | SAT 2017 & 2018, ACT 2017 & 2018 | STR   | Name of the State                                            |
# | act2017_participation | ACT 2017                         | INT   | Participation rate of students  (in percentage) from the State for the 2017 ACT |
# | act2017_eng           | ACT 2017                         | FLOAT | Mean score for the English test for the State                |
# | act2017_math          | ACT 2017                         | FLOAT | Mean score for the Math test for the State                   |
# | act2017_reading       | ACT 2017                         | FLOAT | Mean score for the Reading test for the State                |
# | act2017_science       | ACT 2017                         | FLOAT | Mean score for the Science test for the State                |
# | act2017_composite     | ACT 2017                         | FLOAT | Mean composite score for the State in all the tests (English, Math, Reading & Science) |
# | sat2017_participation | SAT 2017                         | INT   | Participation rate of students  (in percentage) from the State for the 2017 SAT |
# | sat2017_erw           | SAT 2017                         | INT   | Mean score for the Evidence-Based Reading and Writing test for the State |
# | sat2017_math          | SAT 2017                         | INT   | Mean score for the Math test for the State                   |
# | sat2017_total         | SAT 2017                         | INT   | Mean total score for the state in all SAT tests (Evidence-Based Reading and Writing & Math) |
# | act2018_participation | ACT 2018                         | INT   | Participation rate of students  (in percentage) from the State for the 2018 ACT |
# | act2018_composite     | ACT 2018                         | FLOAT | Mean composite score for the State in all the tests (English, Math, Reading & Science) |
# | act2018_eng           | ACT 2018                         | FLOAT | Mean score for the English test for the State                |
# | act2018_math          | ACT 2018                         | FLOAT | Mean score for the Math test for the State                   |
# | act2018_reading       | ACT 2018                         | FLOAT | Mean score for the Reading test for the State                |
# | act2018_science       | ACT 2018                         | FLOAT | Mean score for the Science test for the State                |
# | sat2018_participation | SAT 2018                         | INT   | Participation rate of students  (in percentage) from the State for the 2018 SAT |
# | sat2018_erw           | SAT 2018                         | INT   | Mean score for the Evidence-Based Reading and Writing test for the State |
# | sat2018_math          | SAT 2018                         | INT   | Mean score for the Math test for the State                   |
# | sat2018_total         | SAT 2018                         | INT   | Mean total score for the state in all SAT tests (Evidence-Based Reading and Writing & Math) |

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
act2017_score_filtered = act2017_score[act2017_score["state"] != 'National']
act2017_score_filtered
# Out:
#                    state  act2017_participation  act2017_eng  act2017_math  \
# 1                Alabama                    100         18.9          18.4
# 2                 Alaska                     65         18.7          19.8
# 3                Arizona                     62         18.6          19.8
# 4               Arkansas                    100         18.9          19.0
# 5             California                     31         22.5          22.7
# 6               Colorado                    100         20.1          20.3
# 7            Connecticut                     31         25.5          24.6
# 8               Delaware                     18         24.1          23.4
# 9   District of Columbia                     32         24.4          23.5
# 10               Florida                     73         19.0          19.4
# 11               Georgia                     55         21.0          20.9
# ...

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
combined_2017 = act2017_score_filtered.merge(sat2017_score)
combined_2017
# Out:
#                    state  act2017_participation  act2017_eng  act2017_math  \
# 0                Alabama                    100         18.9          18.4
# 1                 Alaska                     65         18.7          19.8
# 2                Arizona                     62         18.6          19.8
# 3               Arkansas                    100         18.9          19.0
# 4             California                     31         22.5          22.7
# 5               Colorado                    100         20.1          20.3
# 6            Connecticut                     31         25.5          24.6
# 7               Delaware                     18         24.1          23.4
# 8   District of Columbia                     32         24.4          23.5
# 9                Florida                     73         19.0          19.4
# 10               Georgia                     55         21.0          20.9
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
combined_2017.to_csv('../data/combined_2017.csv', index=False)

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
act2018_score = pd.read_csv('../data/act_2018_updated.csv')
sat2018_score = pd.read_csv('../data/sat_2018.csv')

# %%
act2018_score.rename(columns={"State": "state", "Percentage of Students Tested": "act2018_participation", "Average English Score": "act2018_eng", "Average Math Score": "act2018_math","Average Reading Score": "act2018_reading", "Average Science Score": "act2018_science", "Average Composite Score": "act2018_composite"},inplace=True)
act2018_score.columns
# Out:
# Index(['state', 'act2018_participation', 'act2018_composite', 'act2018_eng',
#        'act2018_math', 'act2018_reading', 'act2018_science'],
#       dtype='object')

# %%
sat2018_score.rename(columns={"State":"state","Participation": "sat2018_participation", "Evidence-Based Reading and Writing":"sat2018_erw","Math":"sat2018_math","Total":"sat2018_total"}, inplace=True)
sat2018_score.columns
# Out:
# Index(['state', 'sat2018_participation', 'sat2018_erw', 'sat2018_math',
#        'sat2018_total'],
#       dtype='object')

# %%
sat2018_score = perc_to_int(sat2018_score, 'sat2018_participation')
sat2018_score
# Out:
#                    state  sat2018_participation  sat2018_erw  sat2018_math  \
# 0                Alabama                      6          595           571
# 1                 Alaska                     43          562           544
# 2                Arizona                     29          577           572
# 3               Arkansas                      5          592           576
# 4             California                     60          540           536
# 5               Colorado                    100          519           506
# 6            Connecticut                    100          535           519
# 7               Delaware                    100          505           492
# 8   District of Columbia                     92          497           480
# 9                Florida                     56          550           549
# 10               Georgia                     70          542           522
# ...

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
combined_2018 = act2018_score.merge(sat2018_score)
final = combined_2017.merge(combined_2018)
final
# Out:
#                    state  act2017_participation  act2017_eng  act2017_math  \
# 0                Alabama                    100         18.9          18.4
# 1                 Alaska                     65         18.7          19.8
# 2                Arizona                     62         18.6          19.8
# 3               Arkansas                    100         18.9          19.0
# 4             California                     31         22.5          22.7
# 5               Colorado                    100         20.1          20.3
# 6            Connecticut                     31         25.5          24.6
# 7               Delaware                     18         24.1          23.4
# 8   District of Columbia                     32         24.4          23.5
# 9                Florida                     73         19.0          19.4
# 10               Georgia                     55         21.0          20.9
# ...

# %%
final.to_csv('../data/final.csv', index=False)

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
final.describe().transpose()
# Out:
#                        count         mean        std    min      25%     50%  \
# act2017_participation   51.0    65.254902  32.140842    8.0    31.00    69.0
# act2017_eng             51.0    20.931373   2.353677   16.3    19.00    20.7
# act2017_math            51.0    21.182353   1.981989   18.0    19.40    20.9
# act2017_reading         51.0    22.013725   2.067271   18.1    20.45    21.8
# act2017_science         51.0    21.450980   1.739353   18.2    19.95    21.3
# act2017_composite       51.0    21.519608   2.020695   17.8    19.80    21.4
# sat2017_participation   51.0    39.803922  35.276632    2.0     4.00    38.0
# sat2017_erw             51.0   569.117647  45.666901  482.0   533.50   559.0
# sat2017_math            51.0   556.882353  47.121395  468.0   523.50   548.0
# sat2017_total           51.0  1126.098039  92.494812  950.0  1055.50  1107.0
# act2018_participation   51.0    61.647059  34.080976    7.0    28.50    66.0
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
def std_dev(col):
    n = len(col)
    avg = np.mean(col)
    std_dev = ((1/n)*(sum([(i-avg) ** 2 for i in col]))) ** 0.5
    
    return std_dev

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
sd = {key: std_dev(value) for (key, value) in zip(final.columns[1:], [final[col] for col in final.columns[1:]])}
sd
# Out:
# {'act2017_participation': 31.824175751231806,
#  'act2017_eng': 2.3304876369363363,
#  'act2017_math': 1.9624620273436781,
#  'act2017_reading': 2.0469029314842646,
#  'act2017_science': 1.7222161451443676,
#  'act2017_composite': 2.000786081581989,
#  'sat2017_participation': 34.92907076664508,
#  'sat2017_erw': 45.21697020437866,
#  'sat2017_math': 46.65713364485503,
#  'sat2017_total': 91.58351056778743,
#  'act2018_participation': 33.745194881997506,
#  'act2018_composite': 2.0855261815801147,
#  'act2018_eng': 2.4222536143202795,
#  'act2018_math': 2.015707255555717,
#  'act2018_reading': 2.145891884510421,
#  'act2018_science': 1.8516885484833543,
#  'sat2018_participation': 36.946619223539415,
#  'sat2018_erw': 47.03460978357609,
#  'sat2018_math': 47.30194550378352,
#  'sat2018_total': 93.22742384464433}

# %%
final.describe().transpose()['std']
# Out:
# act2017_participation    32.140842
# act2017_eng               2.353677
# act2017_math              1.981989
# act2017_reading           2.067271
# act2017_science           1.739353
# act2017_composite         2.020695
# sat2017_participation    35.276632
# sat2017_erw              45.666901
# sat2017_math             47.121395
# sat2017_total            92.494812
# act2018_participation    34.080976
# act2018_composite         2.106278
# act2018_eng               2.446356
# act2018_math              2.035765
# act2018_reading           2.167245
# act2018_science           1.870114
# sat2018_participation    37.314256
# sat2018_erw              47.502627
# sat2018_math             47.772623
# sat2018_total            94.155083
# Name: std, dtype: float64

# %%
numpy_sd = {key: np.std(value) for (key, value) in zip(final.columns[1:], [final[col] for col in final.columns[1:]])}
# {key: np.std(value) for (key,value) in 
#                  zip(final.columns[1:], final.iloc[:1] for i in range(1,final.shape[1]))}

# %%
numpy_sd
# Out:
# {'act2017_participation': 31.824175751231806,
#  'act2017_eng': 2.3304876369363363,
#  'act2017_math': 1.9624620273436781,
#  'act2017_reading': 2.0469029314842646,
#  'act2017_science': 1.7222161451443676,
#  'act2017_composite': 2.000786081581989,
#  'sat2017_participation': 34.92907076664508,
#  'sat2017_erw': 45.21697020437866,
#  'sat2017_math': 46.65713364485503,
#  'sat2017_total': 91.58351056778743,
#  'act2018_participation': 33.745194881997506,
#  'act2018_composite': 2.0855261815801147,
#  'act2018_eng': 2.4222536143202795,
#  'act2018_math': 2.015707255555717,
#  'act2018_reading': 2.145891884510421,
#  'act2018_science': 1.8516885484833543,
#  'sat2018_participation': 36.946619223539415,
#  'sat2018_erw': 47.03460978357609,
#  'sat2018_math': 47.30194550378352,
#  'sat2018_total': 93.22742384464433}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# *Answer:* It is the same as the Numpy standard deviation but not against the pandas describe standard deviation.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
ACT_Participation = final[['state','act2017_participation', 'act2018_participation']].sort_values('act2018_participation')
ACT_Participation
# Out:
#                    state  act2017_participation  act2018_participation
# 19                 Maine                      8                      7
# 39          Rhode Island                     21                     15
# 29         New Hampshire                     18                     16
# 7               Delaware                     18                     17
# 38          Pennsylvania                     23                     20
# 22              Michigan                     29                     22
# 47            Washington                     29                     24
# 45               Vermont                     29                     24
# 46              Virginia                     29                     24
# 21         Massachusetts                     29                     25
# 6            Connecticut                     31                     26
# 4             California                     31                     27
# ...

# %%
ACT_English = final[['state','act2017_eng', 'act2018_eng']].sort_values('act2018_eng')
ACT_English
# Out:
#                    state  act2017_eng  act2018_eng
# 28                Nevada         16.3         16.6
# 40        South Carolina         17.5         17.3
# 33        North Carolina         17.8         18.0
# 2                Arizona         18.6         18.2
# 24           Mississippi         18.2         18.2
# 11                Hawaii         17.8         18.2
# 31            New Mexico         18.6         18.3
# 36              Oklahoma         18.5         18.4
# 26               Montana         19.0         18.7
# 0                Alabama         18.9         18.9
# 18             Louisiana         19.4         19.0
# 50               Wyoming         19.4         19.0
# 3               Arkansas         18.9         19.1
# 34          North Dakota         19.0         19.1
# 9                Florida         19.0         19.2
# 35                  Ohio         21.2         19.3
# 42             Tennessee         19.5         19.4
# ...

# %%
ACT_Math = final[['state','act2017_math', 'act2018_math']].sort_values('act2018_math')
ACT_Math
# Out:
#                    state  act2017_math  act2018_math
# 28                Nevada          18.0          17.8
# 24           Mississippi          18.1          18.1
# 40        South Carolina          18.6          18.2
# 0                Alabama          18.4          18.3
# 18             Louisiana          18.8          18.5
# 36              Oklahoma          18.8          18.8
# 3               Arkansas          19.0          18.9
# 11                Hawaii          19.2          19.0
# 42             Tennessee          19.2          19.1
# 31            New Mexico          19.4          19.1
# 33        North Carolina          19.3          19.3
# 9                Florida          19.4          19.3
# 48         West Virginia          19.4          19.4
# 2                Arizona          19.8          19.4
# 17              Kentucky          19.4          19.7
# 25              Missouri          19.9          19.7
# 50               Wyoming          19.8          19.7
# ...

# %%
ACT_Reading = final[['state','act2017_reading', 'act2018_reading']].sort_values('act2018_reading')
ACT_Reading
# Out:
#                    state  act2017_reading  act2018_reading
# 28                Nevada             18.1             18.0
# 40        South Carolina             19.1             18.6
# 24           Mississippi             18.8             18.9
# 11                Hawaii             19.2             19.1
# 2                Arizona             20.1             19.5
# 33        North Carolina             19.6             19.5
# 0                Alabama             19.7             19.6
# 18             Louisiana             19.8             19.6
# 3               Arkansas             19.7             19.7
# 42             Tennessee             20.1             19.9
# 36              Oklahoma             20.1             20.1
# 31            New Mexico             20.4             20.1
# 27              Nebraska             21.9             20.4
# 25              Missouri             20.8             20.5
# 50               Wyoming             20.8             20.6
# ...

# %%
ACT_Science = final[['state','act2017_science', 'act2018_science']].sort_values('act2018_science')
ACT_Science
# Out:
#                    state  act2017_science  act2018_science
# 28                Nevada             18.2             17.9
# 40        South Carolina             18.9             18.5
# 24           Mississippi             18.8             18.6
# 0                Alabama             19.4             19.0
# 11                Hawaii             19.3             19.0
# 18             Louisiana             19.6             19.1
# 2                Arizona             19.8             19.2
# 33        North Carolina             19.3             19.2
# 3               Arkansas             19.5             19.4
# 36              Oklahoma             19.6             19.4
# 9                Florida             19.4             19.5
# 42             Tennessee             19.9             19.6
# 31            New Mexico             20.0             19.7
# 26               Montana             20.5             20.0
# 25              Missouri             20.5             20.0
# ...

# %%
ACT_Composite = final[['state','act2017_composite', 'act2018_composite']].sort_values('act2018_composite')
ACT_Composite
# Out:
#                    state  act2017_composite  act2018_composite
# 28                Nevada               17.8               17.7
# 40        South Carolina               18.7               18.3
# 24           Mississippi               18.6               18.6
# 11                Hawaii               19.0               18.9
# 0                Alabama               19.2               19.1
# 33        North Carolina               19.1               19.1
# 2                Arizona               19.7               19.2
# 18             Louisiana               19.5               19.2
# 36              Oklahoma               19.4               19.3
# 3               Arkansas               19.4               19.4
# 31            New Mexico               19.7               19.4
# 42             Tennessee               19.8               19.6
# 9                Florida               19.8               19.9
# 26               Montana               20.3               20.0
# ...

# %%
SAT_Participation = final[['state','sat2017_participation', 'sat2018_participation']].sort_values('sat2018_participation')
SAT_Participation
# Out:
#                    state  sat2017_participation  sat2018_participation
# 34          North Dakota                      2                      2
# 50               Wyoming                      3                      3
# 41          South Dakota                      3                      3
# 27              Nebraska                      3                      3
# 49             Wisconsin                      3                      3
# 24           Mississippi                      2                      3
# 15                  Iowa                      2                      3
# 44                  Utah                      3                      4
# 23             Minnesota                      3                      4
# 18             Louisiana                      4                      4
# 17              Kentucky                      4                      4
# 16                Kansas                      4                      4
# ...

# %%
SAT_ERW = final[['state','sat2017_erw', 'sat2018_erw']].sort_values('sat2018_erw')
SAT_ERW
# Out:
#                    state  sat2017_erw  sat2018_erw
# 44                  Utah          624          480
# 11                Hawaii          544          480
# 8   District of Columbia          482          497
# 7               Delaware          503          505
# 12                 Idaho          513          508
# 22              Michigan          509          511
# 19                 Maine          513          512
# 13              Illinois          559          513
# 39          Rhode Island          539          513
# 48         West Virginia          558          513
# 5               Colorado          606          519
# 43                 Texas          513          520
# 32              New York          528          534
# 6            Connecticut          530          535
# 29         New Hampshire          532          535
# 4             California          531          540
# 36              Oklahoma          530          541
# ...

# %%
SAT_Math = final[['state','sat2017_math', 'sat2018_math']].sort_values('sat2018_math')
SAT_Math
# Out:
#                    state  sat2017_math  sat2018_math
# 8   District of Columbia           468           480
# 48         West Virginia           528           486
# 7               Delaware           492           492
# 12                 Idaho           493           493
# 22              Michigan           495           499
# 19                 Maine           499           501
# 39          Rhode Island           524           505
# 13              Illinois           556           506
# 5               Colorado           595           506
# 43                 Texas           507           512
# 6            Connecticut           512           519
# 36              Oklahoma           517           521
# 10               Georgia           515           522
# 40        South Carolina           521           523
# 29         New Hampshire           520           528
# 11                Hawaii           541           530
# 44                  Utah           614           530
# ...

# %%
SAT_Total = final[['state','sat2017_total', 'sat2018_total']].sort_values('sat2018_total')
SAT_Total
# Out:
#                    state  sat2017_total  sat2018_total
# 8   District of Columbia            950            977
# 7               Delaware            996            998
# 48         West Virginia           1086            999
# 12                 Idaho           1005           1001
# 44                  Utah           1238           1010
# 11                Hawaii           1085           1010
# 22              Michigan           1005           1011
# 19                 Maine           1012           1013
# 39          Rhode Island           1062           1018
# 13              Illinois           1115           1019
# 5               Colorado           1201           1025
# 43                 Texas           1020           1032
# 6            Connecticut           1041           1053
# 36              Oklahoma           1047           1062
# 29         New Hampshire           1052           1063
# 10               Georgia           1050           1064
# ...

# %%
ACT_Participation = final[['state','act2017_participation', 'act2018_participation']].sort_values('act2018_participation')
ACT_Participation
# Out:
#                    state  act2017_participation  act2018_participation
# 19                 Maine                      8                      7
# 39          Rhode Island                     21                     15
# 29         New Hampshire                     18                     16
# 7               Delaware                     18                     17
# 38          Pennsylvania                     23                     20
# 22              Michigan                     29                     22
# 47            Washington                     29                     24
# 45               Vermont                     29                     24
# 46              Virginia                     29                     24
# 21         Massachusetts                     29                     25
# 6            Connecticut                     31                     26
# 4             California                     31                     27
# ...

# %%
ACT_English = final[['state','act2017_eng', 'act2018_eng']].sort_values('act2018_eng')
ACT_English
# Out:
#                    state  act2017_eng  act2018_eng
# 28                Nevada         16.3         16.6
# 40        South Carolina         17.5         17.3
# 33        North Carolina         17.8         18.0
# 2                Arizona         18.6         18.2
# 24           Mississippi         18.2         18.2
# 11                Hawaii         17.8         18.2
# 31            New Mexico         18.6         18.3
# 36              Oklahoma         18.5         18.4
# 26               Montana         19.0         18.7
# 0                Alabama         18.9         18.9
# 18             Louisiana         19.4         19.0
# 50               Wyoming         19.4         19.0
# 3               Arkansas         18.9         19.1
# 34          North Dakota         19.0         19.1
# 9                Florida         19.0         19.2
# 35                  Ohio         21.2         19.3
# 42             Tennessee         19.5         19.4
# ...

# %%
ACT_Math = final[['state','act2017_math', 'act2018_math']].sort_values('act2018_math')
ACT_Math
# Out:
#                    state  act2017_math  act2018_math
# 28                Nevada          18.0          17.8
# 24           Mississippi          18.1          18.1
# 40        South Carolina          18.6          18.2
# 0                Alabama          18.4          18.3
# 18             Louisiana          18.8          18.5
# 36              Oklahoma          18.8          18.8
# 3               Arkansas          19.0          18.9
# 11                Hawaii          19.2          19.0
# 42             Tennessee          19.2          19.1
# 31            New Mexico          19.4          19.1
# 33        North Carolina          19.3          19.3
# 9                Florida          19.4          19.3
# 48         West Virginia          19.4          19.4
# 2                Arizona          19.8          19.4
# 17              Kentucky          19.4          19.7
# 25              Missouri          19.9          19.7
# 50               Wyoming          19.8          19.7
# ...

# %%
ACT_Reading = final[['state','act2017_reading', 'act2018_reading']].sort_values('act2018_reading')
ACT_Reading
# Out:
#                    state  act2017_reading  act2018_reading
# 28                Nevada             18.1             18.0
# 40        South Carolina             19.1             18.6
# 24           Mississippi             18.8             18.9
# 11                Hawaii             19.2             19.1
# 2                Arizona             20.1             19.5
# 33        North Carolina             19.6             19.5
# 0                Alabama             19.7             19.6
# 18             Louisiana             19.8             19.6
# 3               Arkansas             19.7             19.7
# 42             Tennessee             20.1             19.9
# 36              Oklahoma             20.1             20.1
# 31            New Mexico             20.4             20.1
# 27              Nebraska             21.9             20.4
# 25              Missouri             20.8             20.5
# 50               Wyoming             20.8             20.6
# ...

# %%
ACT_Science = final[['state','act2017_science', 'act2018_science']].sort_values('act2018_science')
ACT_Science
# Out:
#                    state  act2017_science  act2018_science
# 28                Nevada             18.2             17.9
# 40        South Carolina             18.9             18.5
# 24           Mississippi             18.8             18.6
# 0                Alabama             19.4             19.0
# 11                Hawaii             19.3             19.0
# 18             Louisiana             19.6             19.1
# 2                Arizona             19.8             19.2
# 33        North Carolina             19.3             19.2
# 3               Arkansas             19.5             19.4
# 36              Oklahoma             19.6             19.4
# 9                Florida             19.4             19.5
# 42             Tennessee             19.9             19.6
# 31            New Mexico             20.0             19.7
# 26               Montana             20.5             20.0
# 25              Missouri             20.5             20.0
# ...

# %%
ACT_Composite = final[['state','act2017_composite', 'act2018_composite']].sort_values('act2018_composite')
ACT_Composite
# Out:
#                    state  act2017_composite  act2018_composite
# 28                Nevada               17.8               17.7
# 40        South Carolina               18.7               18.3
# 24           Mississippi               18.6               18.6
# 11                Hawaii               19.0               18.9
# 0                Alabama               19.2               19.1
# 33        North Carolina               19.1               19.1
# 2                Arizona               19.7               19.2
# 18             Louisiana               19.5               19.2
# 36              Oklahoma               19.4               19.3
# 3               Arkansas               19.4               19.4
# 31            New Mexico               19.7               19.4
# 42             Tennessee               19.8               19.6
# 9                Florida               19.8               19.9
# 26               Montana               20.3               20.0
# ...

# %%
# states with the lowest mean total score in 2017 for the SAT
print('The state with the lowest mean total score in 2017 is: The District of Columbia')
sat2017_score.sort_values(by='sat2017_total').head()
# [['State','sat2017_total']]
# Out:
# The state with the lowest mean total score in 2017 is: The District of Columbia
#                    state  sat2017_participation  sat2017_erw  sat2017_math  \
# 8   District of Columbia                    100          482           468
# 7               Delaware                    100          503           492
# 12                 Idaho                     93          513           493
# 22              Michigan                    100          509           495
# 19                 Maine                     95          513           499
#
#     sat2017_total
# 8             950
# 7             996
# 12           1005
# 22           1005
# 19           1012

# %%
# states with the lowest mean total score in 2018 for the SAT
print('The state with the lowest mean total score in 2018 is: The District of Columbia')
sat2018_score.sort_values(by='sat2018_total').head()
# Out:
# The state with the lowest mean total score in 2018 is: The District of Columbia
#                    state  sat2018_participation  sat2018_erw  sat2018_math  \
# 8   District of Columbia                     92          497           480
# 7               Delaware                    100          505           492
# 48         West Virginia                     28          513           486
# 12                 Idaho                    100          508           493
# 44                  Utah                      4          480           530
#
#     sat2018_total
# 8             977
# 7             998
# 48            999
# 12           1001
# 44           1010

# %% [markdown]
# District of Columnbia maintains as the state that achieves the lowest mean total score in both years.

# %%
# states with the highest mean total score in 2017 for the SAT
print('The state with the highest mean total score in 2017 is: Minnesota')
sat2017_score.sort_values(by='sat2017_total',ascending=False).head()
# Out:
# The state with the highest mean total score in 2017 is: Minnesota
#         state  sat2017_participation  sat2017_erw  sat2017_math  sat2017_total
# 23  Minnesota                      3          644           651           1295
# 49  Wisconsin                      3          642           649           1291
# 15       Iowa                      2          641           635           1275
# 25   Missouri                      3          640           631           1271
# 16     Kansas                      4          632           628           1260

# %%
# states with the highest mean total score in 2018 for the SAT
print('The state with the highest mean total score in 2018 is: Minnesota')
sat2018_score.sort_values(by='sat2018_total',ascending=False).head()
# Out:
# The state with the highest mean total score in 2018 is: Minnesota
#            state  sat2018_participation  sat2018_erw  sat2018_math  \
# 23     Minnesota                      4          643           655
# 49     Wisconsin                      3          641           653
# 34  North Dakota                      2          640           643
# 15          Iowa                      3          634           631
# 16        Kansas                      4          633           631
#
#     sat2018_total
# 23           1298
# 49           1294
# 34           1283
# 15           1265
# 16           1265

# %% [markdown]
# Minnesota maintains as the state that achieves the highest mean total score in both years. Brilliant.

# %%
# states with the lowest composite score in 2017 for the ACT
print('The state with the lowest composite score in 2017 is: Neveda')
act2017_score_filtered.sort_values(by='act2017_composite').head()
# Out:
# The state with the lowest composite score in 2017 is: Neveda
#              state  act2017_participation  act2017_eng  act2017_math  \
# 29          Nevada                    100         16.3          18.0
# 25     Mississippi                    100         18.2          18.1
# 41  South Carolina                    100         17.5          18.6
# 12          Hawaii                     90         17.8          19.2
# 34  North Carolina                    100         17.8          19.3
#
#     act2017_reading  act2017_science  act2017_composite
# 29             18.1             18.2               17.8
# 25             18.8             18.8               18.6
# 41             19.1             18.9               18.7
# 12             19.2             19.3               19.0
# 34             19.6             19.3               19.1

# %%
# states with the lowest composite score in 2018 for the ACT
print('The state with the lowest composite score in 2018 is: Neveda')
act2018_score.sort_values(by='act2018_composite').head()
# Out:
# The state with the lowest composite score in 2018 is: Neveda
#              state  act2018_participation  act2018_composite  act2018_eng  \
# 28          Nevada                    100               17.7         16.6
# 40  South Carolina                    100               18.3         17.3
# 24     Mississippi                    100               18.6         18.2
# 11          Hawaii                     89               18.9         18.2
# 0          Alabama                    100               19.1         18.9
#
#     act2018_math  act2018_reading  act2018_science
# 28          17.8             18.0             17.9
# 40          18.2             18.6             18.5
# 24          18.1             18.9             18.6
# 11          19.0             19.1             19.0
# 0           18.3             19.6             19.0

# %% [markdown]
# Neveda maintains as the state that achieves the lowest composite score in both years.

# %%
# states with the highest composite score in 2017 for the ACT
print('The state with the highest composite score in 2017 is: New Hampshire')
act2017_score_filtered.sort_values(by='act2017_composite',ascending=False).head()
# Out:
# The state with the highest composite score in 2017 is: New Hampshire
#                    state  act2017_participation  act2017_eng  act2017_math  \
# 30         New Hampshire                     18         25.4          25.1
# 22         Massachusetts                     29         25.4          25.3
# 7            Connecticut                     31         25.5          24.6
# 20                 Maine                      8         24.2          24.0
# 9   District of Columbia                     32         24.4          23.5
#
#     act2017_reading  act2017_science  act2017_composite
# 30             26.0             24.9               25.5
# 22             25.9             24.7               25.4
# 7              25.6             24.6               25.2
# 20             24.8             23.7               24.3
# 9              24.9             23.5               24.2

# %%
# states with the highest composite score in 2018 for the ACT
print('The state with the highest composite score in 2018 is: Connecticut')
act2018_score.sort_values(by='act2018_composite',ascending=False).head()
# Out:
# The state with the highest composite score in 2018 is: Connecticut
#             state  act2018_participation  act2018_composite  act2018_eng  \
# 6     Connecticut                     26               25.6         26.0
# 21  Massachusetts                     25               25.5         25.5
# 29  New Hampshire                     16               25.1         25.1
# 32       New York                     27               24.5         24.2
# 22       Michigan                     22               24.4         24.5
#
#     act2018_math  act2018_reading  act2018_science
# 6           24.8             26.1             24.9
# 21          25.2             25.9             24.7
# 29          24.7             25.6             24.4
# 32          24.2             24.9             24.2
# 22          23.9             24.7             23.9

# %% [markdown]
# Connecticut took over New Hampshire as the state that achieves the highest composite score in 2018, with New Hampshire following closely in 3rd.

# %%
# states with the lowest participation rate in 2017 for the SAT
print('The states with the lowest participation rate in 2017 are: North Dakota, Mississippi and Iowa')
sat2017_score.sort_values(by='sat2017_participation').head()
# Out:
# The states with the lowest participation rate in 2017 are: North Dakota, Mississippi and Iowa
#            state  sat2017_participation  sat2017_erw  sat2017_math  \
# 34  North Dakota                      2          635           621
# 24   Mississippi                      2          634           607
# 15          Iowa                      2          641           635
# 25      Missouri                      3          640           631
# 44          Utah                      3          624           614
#
#     sat2017_total
# 34           1256
# 24           1242
# 15           1275
# 25           1271
# 44           1238

# %%
# states with the lowest participation rate in 2018 for the SAT
print('The state with the lowest participation rate in 2018 is: North Dakota')
sat2018_score.sort_values(by='sat2018_participation').head()
# Out:
# The state with the lowest participation rate in 2018 is: North Dakota
#            state  sat2018_participation  sat2018_erw  sat2018_math  \
# 34  North Dakota                      2          640           643
# 50       Wyoming                      3          633           625
# 41  South Dakota                      3          622           618
# 27      Nebraska                      3          629           623
# 49     Wisconsin                      3          641           653
#
#     sat2018_total
# 34           1283
# 50           1257
# 41           1240
# 27           1252
# 49           1294

# %% [markdown]
# North Dakota is recorded as the state with the lowest participation in both years with Mississippi dropping off.

# %%
# states with the highest participation rate in 2017 for the SAT
print('The states with the highest participation rate in 2017 are: District of Columbia, Michigan, Connecticut, Delaware and New Hampshire')
sat2017_score.sort_values(by='sat2017_participation',ascending=False).head()
# Out:
# The states with the highest participation rate in 2017 are: District of Columbia, Michigan, Connecticut, Delaware and New Hampshire
#                    state  sat2017_participation  sat2017_erw  sat2017_math  \
# 8   District of Columbia                    100          482           468
# 22              Michigan                    100          509           495
# 6            Connecticut                    100          530           512
# 7               Delaware                    100          503           492
# 29         New Hampshire                     96          532           520
#
#     sat2017_total
# 8             950
# 22           1005
# 6            1041
# 7             996
# 29           1052

# %%
# states with the highest participation rate in 2018 for the SAT
print('The states with the highest participation rate in 2017 are: Colorado, Connecticut, Delaware, Michigan and Idaho')
sat2018_score.sort_values(by='sat2018_participation',ascending=False).head(10)
# Out:
# The states with the highest participation rate in 2017 are: Colorado, Connecticut, Delaware, Michigan and Idaho
#                    state  sat2018_participation  sat2018_erw  sat2018_math  \
# 5               Colorado                    100          519           506
# 6            Connecticut                    100          535           519
# 7               Delaware                    100          505           492
# 22              Michigan                    100          511           499
# 12                 Idaho                    100          508           493
# 19                 Maine                     99          512           501
# 13              Illinois                     99          513           506
# 39          Rhode Island                     97          513           505
# 29         New Hampshire                     96          535           528
# 8   District of Columbia                     92          497           480
#
#     sat2018_total
# ...

# %% [markdown]
# Connecticut, Delaware, Michigan are consistent with viewing the standardised test as a necessary progression to college.

# %%
# states with the lowest participation rate in 2017 for the ACT
print('The states with the lowest participation rate in 2017 is: Maine')
act2017_score_filtered.sort_values(by='act2017_participation').head()
# Out:
# The states with the lowest participation rate in 2017 is: Maine
#             state  act2017_participation  act2017_eng  act2017_math  \
# 20          Maine                      8         24.2          24.0
# 30  New Hampshire                     18         25.4          25.1
# 8        Delaware                     18         24.1          23.4
# 40   Rhode Island                     21         24.0          23.3
# 39   Pennsylvania                     23         23.4          23.4
#
#     act2017_reading  act2017_science  act2017_composite
# 20             24.8             23.7               24.3
# 30             26.0             24.9               25.5
# 8              24.8             23.6               24.1
# 40             24.7             23.4               24.0
# 39             24.2             23.3               23.7

# %%
# states with the lowest participation rate in 2018 for the ACT
print('The states with the lowest participation rate in 2018 are: Maine')
act2018_score.sort_values(by='act2018_participation').head()
# Out:
# The states with the lowest participation rate in 2018 are: Maine
#             state  act2018_participation  act2018_composite  act2018_eng  \
# 19          Maine                      7               24.0         23.8
# 39   Rhode Island                     15               24.2         24.4
# 29  New Hampshire                     16               25.1         25.1
# 7        Delaware                     17               23.2         23.7
# 38   Pennsylvania                     20               23.5         23.3
#
#     act2018_math  act2018_reading  act2018_science
# 19          23.6             24.7             23.4
# 39          23.6             25.0             23.5
# 29          24.7             25.6             24.4
# 7           23.1             24.5             23.4
# 38          23.2             24.0             23.1

# %% [markdown]
# Maine has the lowest participants for the ACT in both years.

# %%
# states with the highest participation rate in 2017 for the ACT
print('The states with the highest participation rate in 2017 are: Alabama, Kentucky, Wisconsin, Utah, Tennessee, South Carolina, Oklahoma, North Carolina, Neveda, Montana, Mississippi, Minnesota, Louisiana, Missouri, Wyoming, Colorado and Arkansas')
act2017_score_filtered.sort_values(by='act2017_participation',ascending=False).head(20)
# Out:
# The states with the highest participation rate in 2017 are: Alabama, Kentucky, Wisconsin, Utah, Tennessee, South Carolina, Oklahoma, North Carolina, Neveda, Montana, Mississippi, Minnesota, Louisiana, Missouri, Wyoming, Colorado and Arkansas
#              state  act2017_participation  act2017_eng  act2017_math  \
# 1          Alabama                    100         18.9          18.4
# 18        Kentucky                    100         19.6          19.4
# 50       Wisconsin                    100         19.7          20.4
# 45            Utah                    100         19.5          19.9
# 43       Tennessee                    100         19.5          19.2
# 41  South Carolina                    100         17.5          18.6
# 37        Oklahoma                    100         18.5          18.8
# 34  North Carolina                    100         17.8          19.3
# 29          Nevada                    100         16.3          18.0
# ...

# %%
# states with the highest participation rate in 2018 for the ACT
print('The states with the highest participation rate in 2017 are: Alabama, Kentucky, Wisconsin, Utah, Tennessee, South Carolina, Oklahoma, Ohio, North Carolina, Neveda, Nebraska, Montana, Mississippi, Minnesota, Louisiana, Missouri, Wyoming and Arkansas')
act2018_score.sort_values(by='act2018_participation',ascending=False).head(20)
# Out:
# The states with the highest participation rate in 2017 are: Alabama, Kentucky, Wisconsin, Utah, Tennessee, South Carolina, Oklahoma, Ohio, North Carolina, Neveda, Nebraska, Montana, Mississippi, Minnesota, Louisiana, Missouri, Wyoming and Arkansas
#              state  act2018_participation  act2018_composite  act2018_eng  \
# 0          Alabama                    100               19.1         18.9
# 17        Kentucky                    100               20.2         19.9
# 49       Wisconsin                    100               20.5         19.8
# 44            Utah                    100               20.4         19.7
# 42       Tennessee                    100               19.6         19.4
# 40  South Carolina                    100               18.3         17.3
# 36        Oklahoma                    100               19.3         18.4
# 35            Ohio                    100               20.3         19.3
# ...

# %% [markdown]
# Ohio and Nebraska were added to the list of states with highest participation rate in 2018. Colorado dropped significantly, which will be explored later

# %%
SAT_Participation["rate_change"] =(SAT_Participation['sat2018_participation']-SAT_Participation['sat2017_participation'])

# %%
SAT_Participation.sort_values('rate_change')
# Out:
#                    state  sat2017_participation  sat2018_participation  \
# 9                Florida                     83                     56
# 8   District of Columbia                    100                     92
# 28                Nevada                     26                     23
# 2                Arizona                     30                     29
# 14               Indiana                     63                     63
# 22              Michigan                    100                    100
# 29         New Hampshire                     96                     96
# 6            Connecticut                    100                    100
# 7               Delaware                    100                    100
# 26               Montana                     10                     10
# 16                Kansas                      4                      4
# 34          North Dakota                      2                      2
# ...

# %%
SAT_Participation.sort_values('rate_change')[SAT_Participation['sat2017_participation']==100]
# Out:
# /Users/gabriellechases/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                    state  sat2017_participation  sat2018_participation  \
# 8   District of Columbia                    100                     92
# 22              Michigan                    100                    100
# 6            Connecticut                    100                    100
# 7               Delaware                    100                    100
#
#     rate_change
# 8            -8
# 22            0
# 6             0
# 7             0

# %% [markdown]
# The state that had a rate change from 2017 to 2018 is the District of Columbia with a decrease in participation of 8% on the SAT.

# %%
# states with 100% participation on the SAT for the year 2017 that have a rate change year-to-year
sat2017_100part = sat2017_score[sat2017_score['sat2017_participation'] == 100]
sat2017_100part
# Out:
#                    state  sat2017_participation  sat2017_erw  sat2017_math  \
# 6            Connecticut                    100          530           512
# 7               Delaware                    100          503           492
# 8   District of Columbia                    100          482           468
# 22              Michigan                    100          509           495
#
#     sat2017_total
# 6            1041
# 7             996
# 8             950
# 22           1005

# %%
# states with 100% participation on the SAT for the year 2018 that have a rate change year-to-year
sat2018_100part = sat2018_score[sat2018_score['sat2018_participation'] == 100]
sat2018_100part
# Out:
#           state  sat2018_participation  sat2018_erw  sat2018_math  \
# 5      Colorado                    100          519           506
# 6   Connecticut                    100          535           519
# 7      Delaware                    100          505           492
# 12        Idaho                    100          508           493
# 22     Michigan                    100          511           499
#
#     sat2018_total
# 5            1025
# 6            1053
# 7             998
# 12           1001
# 22           1011

# %%
sat2017_100part.merge(sat2018_100part)
# Out:
#          state  sat2017_participation  sat2017_erw  sat2017_math  \
# 0  Connecticut                    100          530           512
# 1     Delaware                    100          503           492
# 2     Michigan                    100          509           495
#
#    sat2017_total  sat2018_participation  sat2018_erw  sat2018_math  \
# 0           1041                    100          535           519
# 1            996                    100          505           492
# 2           1005                    100          511           499
#
#    sat2018_total
# 0           1053
# 1            998
# 2           1011

# %%
# states that fell below the 100% participation 
sat2017_100part[~sat2017_100part['state'].isin(sat2018_100part['state'])]
# Out:
#                   state  sat2017_participation  sat2017_erw  sat2017_math  \
# 8  District of Columbia                    100          482           468
#
#    sat2017_total
# 8            950

# %%
# states that grew to 100% participation
sat2018_100part[~sat2018_100part['state'].isin(sat2017_100part['state'])]
# Out:
#        state  sat2018_participation  sat2018_erw  sat2018_math  sat2018_total
# 5   Colorado                    100          519           506           1025
# 12     Idaho                    100          508           493           1001

# %%
# states with 100% participation on the ACT for the year 2017 that have a rate change year-to-year
act2017_100part = act2017_score_filtered[act2017_score_filtered['act2017_participation'] == 100]
act2017_100part
# Out:
#              state  act2017_participation  act2017_eng  act2017_math  \
# 1          Alabama                    100         18.9          18.4
# 4         Arkansas                    100         18.9          19.0
# 6         Colorado                    100         20.1          20.3
# 18        Kentucky                    100         19.6          19.4
# 19       Louisiana                    100         19.4          18.8
# 24       Minnesota                    100         20.4          21.5
# 25     Mississippi                    100         18.2          18.1
# 26        Missouri                    100         19.8          19.9
# 27         Montana                    100         19.0          20.2
# 29          Nevada                    100         16.3          18.0
# 34  North Carolina                    100         17.8          19.3
# 37        Oklahoma                    100         18.5          18.8
# 41  South Carolina                    100         17.5          18.6
# ...

# %%
# states with 100% participation on the ACT for the year 2018 that have a rate change year-to-year
act2018_100part = act2018_score[act2018_score['act2018_participation'] == 100]
act2018_100part
# Out:
#              state  act2018_participation  act2018_composite  act2018_eng  \
# 0          Alabama                    100               19.1         18.9
# 3         Arkansas                    100               19.4         19.1
# 17        Kentucky                    100               20.2         19.9
# 18       Louisiana                    100               19.2         19.0
# 24     Mississippi                    100               18.6         18.2
# 25        Missouri                    100               20.0         19.5
# 26         Montana                    100               20.0         18.7
# 27        Nebraska                    100               20.1         19.4
# 28          Nevada                    100               17.7         16.6
# 33  North Carolina                    100               19.1         18.0
# 35            Ohio                    100               20.3         19.3
# 36        Oklahoma                    100               19.3         18.4
# ...

# %%
# states that fell below the 100% participation 
act2017_100part[~act2017_100part['state'].isin(act2018_100part['state'])]
# Out:
#         state  act2017_participation  act2017_eng  act2017_math  \
# 6    Colorado                    100         20.1          20.3
# 24  Minnesota                    100         20.4          21.5
#
#     act2017_reading  act2017_science  act2017_composite
# 6              21.2             20.9               20.8
# 24             21.8             21.6               21.5

# %%
# states that grew to 100% participation
act2018_100part[~act2018_100part['state'].isin(act2017_100part['state'])]
# Out:
#        state  act2018_participation  act2018_composite  act2018_eng  \
# 27  Nebraska                    100               20.1         19.4
# 35      Ohio                    100               20.3         19.3
#
#     act2018_math  act2018_reading  act2018_science
# 27          19.8             20.4             20.1
# 35          20.3             20.8             20.4

# %% [markdown]
# The table belows list the states where more than 50% of high school seniors took the SAT in 2017. 53% of students California, for example, has taken the standardised test.

# %%
# states with more than 50% participation rates for SAT in 2017
sat2017_50part = sat2017_score[sat2017_score['sat2017_participation'] > 50][['state','sat2017_participation']].sort_values('sat2017_participation')
sat2017_50part
# Out:
#                    state  sat2017_participation
# 4             California                     53
# 11                Hawaii                     55
# 45               Vermont                     60
# 10               Georgia                     61
# 43                 Texas                     62
# 14               Indiana                     63
# 47            Washington                     64
# 46              Virginia                     65
# 38          Pennsylvania                     65
# 32              New York                     67
# 20              Maryland                     69
# 30            New Jersey                     70
# 39          Rhode Island                     71
# 21         Massachusetts                     76
# 9                Florida                     83
# 12                 Idaho                     93
# 19                 Maine                     95
# 29         New Hampshire                     96
# 8   District of Columbia                    100
# ...

# %%
sat2017_50part.count()
# Out:
# state                    22
# sat2017_participation    22
# dtype: int64

# %% [markdown]
# The table belows list the states where more than 50% of high school seniors took the SAT in 2018. California has increased its number of testers to 60% with North Carolina making the list of at least half of students having taken the standardised test.

# %%
# states with more than 50% participation rates for SAT in 2018
sat2018_50part = sat2018_score[sat2018_score['sat2018_participation'] > 50][['state','sat2018_participation']].sort_values('sat2018_participation')
sat2018_50part
# Out:
#                    state  sat2018_participation
# 33        North Carolina                     52
# 40        South Carolina                     55
# 9                Florida                     56
# 11                Hawaii                     56
# 4             California                     60
# 14               Indiana                     63
# 45               Vermont                     64
# 43                 Texas                     66
# 46              Virginia                     68
# 47            Washington                     69
# 10               Georgia                     70
# 38          Pennsylvania                     70
# 20              Maryland                     76
# 32              New York                     79
# 21         Massachusetts                     80
# 30            New Jersey                     82
# 8   District of Columbia                     92
# 29         New Hampshire                     96
# 39          Rhode Island                     97
# ...

# %%
# states with more than 50% participation rates for ACT in 2017
print('The table belows list the states where more than 50% of high school seniors recorded has taken the ACT in 2017.')
act2017_50part = act2017_score_filtered[act2017_score_filtered['act2017_participation'] > 50][['state','act2017_participation']].sort_values('act2017_participation')
act2017_50part
# Out:
# The table belows list the states where more than 50% of high school seniors recorded has taken the ACT in 2017.
#              state  act2017_participation
# 11         Georgia                     55
# 3          Arizona                     62
# 2           Alaska                     65
# 32      New Mexico                     66
# 16            Iowa                     67
# 49   West Virginia                     69
# 10         Florida                     73
# 17          Kansas                     73
# 36            Ohio                     75
# 42    South Dakota                     80
# 28        Nebraska                     84
# 12          Hawaii                     90
# 14        Illinois                     93
# 35    North Dakota                     98
# 34  North Carolina                    100
# 43       Tennessee                    100
# 41  South Carolina                    100
# 37        Oklahoma                    100
# 45            Utah                    100
# ...

# %%
act2017_50part.count()
# Out:
# state                    31
# act2017_participation    31
# dtype: int64

# %%
# states with more than 50% participation rates for ACT in 2018
print('Likewise, in 2018, the following shows the list of states with more than 50% participation.')
act2018_50part = act2018_score[act2018_score['act2018_participation'] > 50][['state','act2018_participation']].sort_values('act2018_participation')
act2018_50part
# Out:
# Likewise, in 2018, the following shows the list of states with more than 50% participation.
#              state  act2018_participation
# 10         Georgia                     53
# 48   West Virginia                     65
# 2          Arizona                     66
# 9          Florida                     66
# 31      New Mexico                     67
# 15            Iowa                     68
# 16          Kansas                     71
# 41    South Dakota                     77
# 11          Hawaii                     89
# 34    North Dakota                     98
# 23       Minnesota                     99
# 35            Ohio                    100
# 36        Oklahoma                    100
# 0          Alabama                    100
# 42       Tennessee                    100
# 40  South Carolina                    100
# 44            Utah                    100
# 26         Montana                    100
# 28          Nevada                    100
# ...

# %%
# compare 2 different exams participation
plt.scatter(final['sat2017_participation'],final['sat2017_total'])
plt.title('SAT Participation vs Total in 2017',size=17)
plt.savefig('../graph/sat2017t.jpg')

# %%
plt.scatter(final['sat2017_participation'],final['act2017_participation'])
plt.title('SAT vs ACT Participation in 2017',size=17)
plt.savefig('../graph/201776.jpg')

# %%
plt.scatter(final['sat2018_participation'],final['act2018_participation'])
plt.title('SAT vs ACT Participation in 2018',size=17)
plt.savefig('../graph/2018.jpg')

# %%
plt.scatter(sat2017_score['sat2017_participation'],sat2017_score['sat2017_total'])
plt.title('SAT Participation vs Total in 2017',size=17)
plt.savefig('../graph/20175.jpg')

# %%
plt.scatter(act2017_score_filtered['act2017_participation'],act2017_score_filtered['act2017_composite'])
plt.title('ACT Participation vs Composite in 2017',size=17)
plt.savefig('../graph/20174.jpg')

# %%
plt.scatter(act2017_score_filtered['act2017_participation'],act2017_score_filtered['act2017_composite'])
plt.title('ACT Participation vs Composite in 2017',size=17)
plt.savefig('../graph/2017_Part.jpg')

# %%
plt.scatter(act2018_score['act2018_participation'],act2018_score['act2018_composite'])
plt.title('ACT Participation vs Composite in 2018',size=17)
plt.savefig('../graph/20182.jpg')

# %%
plt.scatter(act2018_score['act2018_participation'],act2018_score['act2018_composite'])
plt.title('ACT Participation vs Composite in 2018',size=17)
# Out:
# Text(0.5, 1.0, 'ACT Participation vs Composite in 2018')

# %%
plt.scatter(sat2018_score['sat2018_participation'],sat2018_score['sat2018_total'])
plt.title('SAT Participation vs Total in 2018',size=17)
plt.savefig('../graph/2018t.jpg')

# %%
final.columns
# Out:
# Index(['state', 'act2017_participation', 'act2017_eng', 'act2017_math',
#        'act2017_reading', 'act2017_science', 'act2017_composite',
#        'sat2017_participation', 'sat2017_erw', 'sat2017_math', 'sat2017_total',
#        'act2018_participation', 'act2018_composite', 'act2018_eng',
#        'act2018_math', 'act2018_reading', 'act2018_science',
#        'sat2018_participation', 'sat2018_erw', 'sat2018_math',
#        'sat2018_total'],
#       dtype='object')

# %% [markdown]
# There are large differences in tester participation rates in some states which might bring biases in the results of certain analysis, which will be explored later.
#
# In 2017, the highest average SAT scores were found in the states of Minnesota, Wisconsin, and Iowa, where average total scores were over 1270. It’s worth noting that in these states, overall participation was quite low, with only 2 to 3% of students taking the test.
#
# This pattern holds true across the board, with higher scoring states having lower participation rates. This is likely due to state preference or requirements related to the test. Students are not likely to take both the ACT and the SAT unless they know they will score well, and when given the choice, students often choose the test that they believe they’ll score higher on.
#
# Similar states appear to have the same deduction year on year. Delaware, for instance, has low average SAT scores but has the highest SAT participation rates. The lowest average SAT scores were found in the states of Delaware and the District of Columbia where average total scores were all below 1000. On the other hand, highest mean SAT scores - Minnesota, Wisconsin, North Dakota, Missouri, Iowa - all have very low participation rates in the test. An inverse relationship between participation and average score in inferred here, with all the lowest performing states having participation rates above 90%. The analysis that students who do not choose and take the test as part of the requirement or a mandatory legality shows a lower below-average scores holds true as well.
#
# Mainly, there is selection biasness. Students who took the SAT test in states that prefer ACT tend to achieve higher average scores, especially if those students are looking for scholorships or moving out of state.
#
# West Virginia, however,shows low average SAT scores at low end participation rates. In 2018, it sees an increase in participation too 100% despite not having a mandatory requirement and also because the state law regarding ACT terminated in 2018, and West Virginia has fee coverage for all public school students - (https://www.wsaz.com/content/news/All-WVa-high-school-juniors-to-begin-taking-SAT-exam-beginning-Spring-2018-444248263.html)
#
# In 2018, high school students in the states of Minnesota, and Wisconsin achieved the highest average SAT scores with North Dakota added to the top-three list. The overall participation was between 2 to 3%.
#
# A total of 17 states have 100% participation rates for the ACT in 2017 which can be deduced that ACT might be simply the prefered test as compared to the SAT.
#
# Because higher participation tends to be associated with lower average scores, it is hard to compare SAT and ACT scores by state. Most states with high participation rates in one test have low participation rates, in other words, states that have high averages on one test, have low averages for the other. This is explored in further analysis in a second.
#
# The inverse relationship can be also seen in the ACT data. Minnesota, for example, despite 100% participation, is ranked low in terms of ACT composite score in the year 2017.
#
# Florida, Georgia and Hawaii were the only states that has more than 50% participation on both tests in consecutive years. These states does not mandate students to sit for any one of the two tests. In both years, Hawaii scored best on the SAT and Georgia scored best on the ACT. Both North Carolina and South Carolina require ACT testing which also joined those three states in achieving a participation rate of above 50% SAT in 2018.

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
import seaborn as sns

# %%
plt.figure(figsize=(15,15))
sns.heatmap(final.corr(),annot=True,cmap='RdGy')
plt.title('Correlation between ACT and SAT Scores in both 2017 and 2018')
# plt.savefig('../graph/corr.jpg')
# Out:
# Text(0.5, 1, 'Correlation between ACT and SAT Scores in both 2017 and 2018')

# %% [markdown]
# As we have analysed, average scores are highly negatively correlation with rate of participation on a given test. This confirms a selection bias effect.
#
# Mean scores on subject are highly correlated with mean scores for subject of the other test, or total scores for that test. If a state has high scores on the SAT because either due to low participation or students are high achievers. This holds for 2 years.
#
# Mean subject scores of the SAT are quite negatively correlated with mean scores on ACT, and vice versa. Again, due to the selection bias effect where higher ACT scores  > lower SAT participation > higher ACT participation > lower ACT scores).
#
# Participation rates on a test is quite positively correlated against scores of the other test. This could be because higher SAT participation > lower ACT participation > higher ACT scores.

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_hist(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2))
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(15,10))
    fig.subplots_adjust(hspace=0.5)
    ax = ax.ravel() # to turn matrix to a vector for iteration purposes
    for i, column in enumerate(list_of_columns):
        ax[i].hist(dataframe[column], bins=15)
        ax[i].set_title(list_of_titles[i], size=15)
        ax[i].set_xlabel(list_of_xlabels[i])

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %% [markdown]
# From the diagrams below, mean and median indicate the centre and skewness, standard deviation and 25% or 75% quartiles indicate spread, minimum and maximum indicate range.
#
# The histogram on participation rates indicates that the distributions are somewhat trimodal. SAT has a huge peak around 0 and a smaller peak around 1. ACT has a huge peak around 1 and a smaller peak around 0. Both display a center peaks.
#
# Distribution for both years did not change much from 2017 to 2018. SAT has a number of states with very low single digit participation rate of less than 10%, of the median to 75%, of the 100% participation. The ACT barely compares to the SAT with states of less than 10% participation, with largely concentrated at or near 100%.
#
# The histograms on math scores is a little like a normal distribution, a slight right skew.
#
# The histograms of reading/ verbal scores is distinctive bimodal with a  peak in the middle and a slight peak at the higher end. This shows there are limitations to the descriptive statistics.

# %%
# participation rates for SAT and ACT 
print('Data concentrates at the extreme ends. It does not follow a normal distribution.')
subplot_hist(final,['sat2017_participation','sat2018_participation','act2017_participation','act2018_participation'],['2017 SAT Participation Rates', '2018 SAT Participation Rates', '2017 ACT Participation Rates', '2018 ACT Participation Rates'], ['Rates in %', 'Rates in %','Rates in %', 'Rates in %'])
plt.savefig('../graph/allrates.jpg')
# Out:
# Data concentrates at the extreme ends. It does not follow a normal distribution.

# %%
# math scores for SAT and ACT 
print('There are two groups of data in these diagrams.')
subplot_hist(final,['sat2017_math','sat2018_math','act2017_math','act2018_math'],['SAT MATH SCORES IN 2017', 'SAT MATH SCORES IN 2018','ACT MATH SCORES IN 2017','ACT MATH SCORES IN 2018'],['Math Scores', 'Math Scores', 'Math Scores', 'Math Scores'])
# Out:
# There are two groups of data in these diagrams.

# %%
# ERW scores for SAT and ACT 
print('The diagram shows disparity in the participation.')
subplot_hist(final,['sat2017_erw','sat2018_erw','act2017_reading','act2018_reading'],
             ['SAT 2017 Evidence-Based Reading and Writing Scores', 'SAT 2018 Evidence-Based Reading and Writing Scores', 'ACT 2017 Reading Scores', 'ACT 2018 Reading Scores'],
             ['Reading and Writing Scores', 'Reading and Writing Scores', 'Reading and Writing Scores', 'Reading and Writing Scores'])
# Out:
# The diagram shows disparity in the participation.

# %% [markdown]
# It should actually follow a normal distribution but these histograms contradicts the underlying assumption.

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %% [markdown]
# These scatter plots exhibit a downward trend but not accurate for forecasting nonetheless. It's like stars in the dark sky. There is weak correlation. The degree of relationship is inverse, for instance a 21 average score in ACT to a 620 in SAT, a certain state shows high school seniors focuses and performs better in one test as compared to the other. The preference for one standardised test over another tends to be quite geographical in nature. In states with high SAT participation, ACT participation tends to be much lower, and vice versa.
#
# Most states maintain the total SAT score from 2017 to 2018. Most states maintain the composite ACT score from 2017 to 2018. For the ACT Composite Scores in 2017 and 2018, most states follow the trend as seen in the congretion of dots along the best fit line.

# %%
sns.regplot(x=final['sat2017_math'], y=final['act2017_math'])
plt.title('SAT vs. ACT MATH SCORES in 2017',size=17)
plt.xlabel('SAT',size=12)
plt.ylabel('ACT',size=12)
# Out:
# Text(0, 0.5, 'ACT')

# %%
sns.regplot(x=final['sat2017_erw'], y=final['act2017_reading'])
plt.title('SAT vs. ACT VERBAL/READING SCORES in 2017',size=17)
plt.xlabel('SAT',size=12)
plt.ylabel('ACT',size=12)
# Out:
# Text(0, 0.5, 'ACT')

# %%
sns.regplot(x=final['sat2017_total'], y=final['act2017_composite'])
plt.title('SAT vs. ACT TOTAL/COMPOSITE scores in 2017',size=17)
plt.xlabel('SAT',size=12)
plt.ylabel('ACT',size=12)
# Out:
# Text(0, 0.5, 'ACT')

# %%
sns.regplot(x=final['sat2017_total'], y=final['sat2018_total'])
plt.title('SAT TOTAL scores in 2017 and 2018',size=17)
plt.xlabel('SAT 2017',size=12)
plt.ylabel('SAT 2018',size=12)
plt.savefig('../graph/sat.jpg')

# %%
sns.regplot(x=final['act2017_composite'], y=final['act2018_composite'])
plt.title('ACT COMPOSITE scores in 2017 and 2018',size=17)
plt.xlabel('ACT 2017',size=12)
plt.ylabel('ACT 2018',size=12)
plt.savefig('../graph/2017act.jpg')

# %%
def subplot_scatter(dataframe,xaxis_name,yaxis_name,xaxis_label,yaxis_label,title):
    plt.figure(figsize=(10,8))
    x_data = final[xaxis_name]
    y_data = final[yaxis_name]
    plt.scatter(x_data,y_data)
    plt.title(title,fontsize=17)
    plt.xlabel(xaxis_label,fontsize=12)
    plt.ylabel(yaxis_label,fontsize=12)

# %%
subplot_scatter(final,'sat2017_math','act2017_math','SAT MATH SCORES IN 2017', 'ACT MATH SCORES IN 2017','2017 MATH SCORES')

# %%
subplot_scatter(final,'sat2017_erw','act2017_reading','SAT ERW SCORES IN 2017', 'ACT READING SCORES IN 2017','2017 Verbal/Reading Scores')

# %%
subplot_scatter(final,'sat2017_total','act2017_composite','TOTAL SCORES FOR SAT IN 2017', 'COMPOSITE SCORES FOR ACT IN 2017','2017 Scores')

# %%
subplot_scatter(final,'sat2017_total','sat2018_total','FOR THE YEAR 2017', 'FOR THE YEAR 2018', 'SAT Total Scores 2017/2018')

# %%
subplot_scatter(final,'act2017_composite','act2018_composite','FOR THE YEAR 2017', 'FOR THE YEAR 2018', 'ACT Composite Scores 2017/2018')

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
print('There is an increase the average participation of the SAT from 2017 to 2018 as seen from the higher 50% percentile line.')
sns.boxplot(data = SAT_Participation[['sat2017_participation','sat2018_participation']])
plt.title('Boxplot of SAT Participation in 2017 and 2018',size=17)
plt.xlabel('Year of SAT',size=12)
plt.ylabel('Participation rate ',size=12)
# Out:
# There is an increase the average participation of the SAT from 2017 to 2018 as seen from the higher 50% percentile line.
# Text(0, 0.5, 'Participation rate ')

# %%
sns.boxplot(data = SAT_ERW[['sat2017_erw','sat2018_erw']])
plt.title('Boxplot of SAT Evidence-Based Reading and Writing Scores in 2017 and 2018',size=17)
plt.xlabel('Year of SAT',size=12)
plt.ylabel('ERW Scores',size=12)
# Out:
# Text(0, 0.5, 'ERW Scores')

# %%
sns.boxplot(data = SAT_Math[['sat2017_math','sat2018_math']])
plt.title('Boxplot of SAT Math Scores in 2017 and 2018',size=17)
plt.xlabel('Year of SAT',size=12)
plt.ylabel('Math Scores',size=12)
# Out:
# Text(0, 0.5, 'Math Scores')

# %%
sns.boxplot(data = SAT_Total[['sat2017_total','sat2018_total']])
plt.title('Boxplot of SAT Total Scores in 2017 and 2018',size=17)
plt.xlabel('Year of SAT',size=12)
plt.ylabel('Total Scores',size=12)
# Out:
# Text(0, 0.5, 'Total Scores')

# %%
print('As compared to the SAT, the average participation for the ACT does not differ as much though rather than an increase, there is a slight decrease in participation as seen from the lower 50% percentile line.')
sns.boxplot(data = ACT_Participation[['act2017_participation','act2018_participation']])
plt.title('Boxplot of ACT Participation Rates in 2017 and 2018',size=17)
plt.xlabel('Year of ACT',size=12)
plt.ylabel('Participation Rate ',size=12)
# Out:
# As compared to the SAT, the average participation for the ACT does not differ as much though rather than an increase, there is a slight decrease in participation as seen from the lower 50% percentile line.
# Text(0, 0.5, 'Participation Rate ')

# %% [markdown]
# Getting into specifics, the scores of the core subjects for the test stays quite the same at the average and at the 25% and 75% percentile as well. There is however, a slight drop in the average english score in 2018.

# %%
sns.boxplot(data = ACT_English[['act2017_eng','act2018_eng']])
plt.title('Boxplot of ACT English Scores in 2017 and 2018',size=17)
plt.xlabel('Year of ACT',size=12)
plt.ylabel('English Scores',size=12)
# Out:
# Text(0, 0.5, 'English Scores')

# %%
sns.boxplot(data = ACT_Math[['act2017_math','act2018_math']])
plt.title('Boxplot of ACT Math Scores in 2017 and 2018',size=17)
plt.xlabel('Year of ACT',size=12)
plt.ylabel('Math Scores',size=12)
# Out:
# Text(0, 0.5, 'Math Scores')

# %%
sns.boxplot(data = ACT_Reading[['act2017_reading','act2018_reading']])
plt.title('Boxplot of ACT Reading Scores in 2017 and 2018',size=17)
plt.xlabel('Year of ACT',size=12)
plt.ylabel('Reading Scores',size=12)
# Out:
# Text(0, 0.5, 'Reading Scores')

# %%
sns.boxplot(data = ACT_Science[['act2017_science','act2018_science']])
plt.title('Boxplot of ACT Science Scores in 2017 and 2018',size=17)
plt.xlabel('Year of ACT',size=12)
plt.ylabel('Science Scores',size=12)
# Out:
# Text(0, 0.5, 'Science Scores')

# %%
sns.boxplot(data = ACT_Composite[['act2017_composite','act2018_composite']])
plt.title('Boxplot of ACT Composite Scores in 2017 and 2018',size=17)
plt.xlabel('Year of ACT',size=12)
plt.ylabel('Composite Scores',size=12)
# Out:
# Text(0, 0.5, 'Composite Scores')

# %%
sns.boxplot(data = final[['act2017_participation','sat2017_participation']])
plt.title('2017 Participation Boxplot',size=17)
plt.xlabel('Test',size=12)
plt.ylabel('% Rates',size=12)
plt.savefig('../graph/2017_Part.jpg')

# %%
sns.boxplot(data = final[['act2018_participation','sat2018_participation']])
plt.title('2018 Participation Boxplot',size=17)
plt.xlabel('Test',size=12)
plt.ylabel('% Rates',size=12)
plt.savefig('../graph/2018_Part.jpg')

# %%
ACT_comparision = final[['act2017_participation','act2018_participation','act2017_composite','act2018_composite']]
ACT_comparision
# Out:
#     act2017_participation  act2018_participation  act2017_composite  \
# 0                     100                    100               19.2
# 1                      65                     33               19.8
# 2                      62                     66               19.7
# 3                     100                    100               19.4
# 4                      31                     27               22.8
# 5                     100                     30               20.8
# 6                      31                     26               25.2
# 7                      18                     17               24.1
# 8                      32                     32               24.2
# 9                      73                     66               19.8
# 10                     55                     53               21.4
# 11                     90                     89               19.0
# 12                     38                     36               22.3
# ...

# %%
fig, ax = plt.subplots(1,2,sharey=True,figsize=(15,10))

final.boxplot(['sat2017_participation', 'sat2017_erw', 'sat2017_math', 'sat2017_total'],ax=ax[0])
final.boxplot(['sat2018_participation', 'sat2018_erw', 'sat2018_math','sat2018_total'], ax=ax[1])
ax[0].set_title('Boxplot of SAT Scores in 2017', fontsize=17)
ax[1].set_title('Boxplot of SAT Scores in 2018', fontsize=17)
ax[0].set_ylabel('Scores', fontsize=12)
ax[0].set_xticklabels(['2017 SAT PARTICIPATION', '2017 SAT ERW', '2017 SAT MATH','2017 SAT TOTAL'], rotation=40)
ax[1].set_xticklabels(['2018 SAT PARTICIPATION', '2018 SAT ERW', '2018 SAT MATH','2018 SAT TOTAL'], rotation=40)
# Out:
# [Text(0, 0, '2018 SAT PARTICIPATION'),
#  Text(0, 0, '2018 SAT ERW'),
#  Text(0, 0, '2018 SAT MATH'),
#  Text(0, 0, '2018 SAT TOTAL')]

# %%
plt.figure(figsize=(15,10))

final.boxplot(column = ['sat2017_participation', 'sat2017_erw', 'sat2017_math', 'sat2017_total', 'sat2018_participation', 'sat2018_erw', 'sat2018_math','sat2018_total'])
plt.title('Boxplot of SAT Scores 2017/2018', fontsize=17)
plt.ylabel('Scores', fontsize=12)
plt.xticks(rotation=40);

# %%
fig, ax = plt.subplots(1,2,sharey=True,figsize=(15,10))

final.boxplot(['act2017_participation', 'act2017_eng', 'act2017_math','act2017_reading', 'act2017_science', 'act2017_composite'],ax=ax[0])
final.boxplot(['act2018_participation', 'act2018_eng','act2018_math', 'act2018_reading', 'act2018_science','act2018_composite'], ax=ax[1])
ax[0].set_title('Boxplot of ACT Scores in 2017', fontsize=17)
ax[1].set_title('Boxplot of ACT Scores in 2018', fontsize=17)
ax[0].set_ylabel('Scores', fontsize=12)
ax[0].set_xticklabels(['2017 ACT PARTICIPATION', '2017 ACT ENGLISH', '2017 ACT MATH', '2017 ACT READING', '2017 ACT SCIENCE','2017 ACT COMPOSITE'], rotation=40)
ax[1].set_xticklabels(['2017 ACT PARTICIPATION', '2017 ACT ENGLISH', '2017 ACT MATH', '2017 ACT READING', '2017 ACT SCIENCE','2017 ACT COMPOSITE'], rotation=40)
# Out:
# [Text(0, 0, '2017 ACT PARTICIPATION'),
#  Text(0, 0, '2017 ACT ENGLISH'),
#  Text(0, 0, '2017 ACT MATH'),
#  Text(0, 0, '2017 ACT READING'),
#  Text(0, 0, '2017 ACT SCIENCE'),
#  Text(0, 0, '2017 ACT COMPOSITE')]

# %%
plt.figure(figsize=(15,10))

final.boxplot(column = ['act2017_participation', 'act2017_eng', 'act2017_math',
       'act2017_reading', 'act2017_science', 'act2017_composite', 'act2018_participation', 'act2018_eng',
       'act2018_math', 'act2018_reading', 'act2018_science', 'act2018_composite'])
plt.title('Boxplot of ACT Scores 2017/2018', fontsize=17)
plt.ylabel('Scores', fontsize=12)
plt.xticks(rotation=40);

# %%
fig, ax = plt.subplots(nrows=5,ncols=4, figsize=(20,20))

for i,col in enumerate(list(final.columns.values)[1:]):
    a = final.boxplot(col, ax = ax.flatten()[i])

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
SAT_comparision = final[['sat2017_participation','sat2018_participation','sat2017_total','sat2018_total']]
SAT_comparision
# Out:
#     sat2017_participation  sat2018_participation  sat2017_total  sat2018_total
# 0                       5                      6           1165           1166
# 1                      38                     43           1080           1106
# 2                      30                     29           1116           1149
# 3                       3                      5           1208           1169
# 4                      53                     60           1055           1076
# 5                      11                    100           1201           1025
# 6                     100                    100           1041           1053
# 7                     100                    100            996            998
# 8                     100                     92            950            977
# 9                      83                     56           1017           1099
# 10                     61                     70           1050           1064
# ...

# %% [markdown]
# There are a number of states that has a large increase in SAT participation from 2017 to 2018. Rising growth in participation for the SAT can help with analysis how and where resources should be placed to improve participation.

# %%
difference_SAT = SAT_Participation[['state','rate_change']].sort_values('rate_change')

# %%
type(difference_SAT)
# Out:
# pandas.core.frame.DataFrame

# %%
difference_SAT.index = difference_SAT['state']

# %%
difference_SAT()
# Out:
#                                      state  rate_change
# state
# Florida                            Florida          -27
# District of Columbia  District of Columbia           -8
# Nevada                              Nevada           -3
# Arizona                            Arizona           -1
# Indiana                            Indiana            0
# Michigan                          Michigan            0
# New Hampshire                New Hampshire            0
# Connecticut                    Connecticut            0
# Delaware                          Delaware            0
# Montana                            Montana            0
# Kansas                              Kansas            0
# North Dakota                  North Dakota            0
# Wyoming                            Wyoming            0
# South Dakota                  South Dakota            0
# Nebraska                          Nebraska            0
# Wisconsin                        Wisconsin            0
# ...

# %%
difference_SAT[(difference_SAT['rate_change'] > 20) | (difference_SAT['rate_change'] < -10)]['rate_change'].sort_values().plot(kind='barh',figsize=(7,7))
plt.xlabel('Rate Change')
# Out:
# Text(0.5, 0, 'Rate Change')

# %% [markdown]
# Illinois has a massive increase in participation rates between 2017 and 2018, as they traded the ACT for the SAT so their participation rate fell to 43% and SAT's rose from 9%.
#
# Colorado, likewise, shows significant gains in SAT participation after removing the mandate of taking the ACT.
# Rhode Island and Florida have shown increases from 70-85% to near full participation.
#
# West Virginia shows opportunity as an area for growth, rising to 28% participation in 2018, while ACT rate fell, possibly from no legality.
#
# States like Nebraska and Ohio have 100% ACT participation in 2018, from 84% and 75% ACT rates in 2017, respectively. This is possibly from state policy changes where ACT is a mandatory test.

# %%
ACT_Participation["rate_change_act"] = (ACT_Participation['act2018_participation']-ACT_Participation['act2017_participation'])

# %%
ACT_Participation.sort_values('rate_change_act')
# Out:
#                    state  act2017_participation  act2018_participation  \
# 5               Colorado                    100                     30
# 13              Illinois                     93                     43
# 1                 Alaska                     65                     33
# 9                Florida                     73                     66
# 22              Michigan                     29                     22
# 39          Rhode Island                     21                     15
# 47            Washington                     29                     24
# 45               Vermont                     29                     24
# 46              Virginia                     29                     24
# 6            Connecticut                     31                     26
# 43                 Texas                     45                     41
# 32              New York                     31                     27
# ...

# %%
difference_ACT = ACT_Participation[['state','rate_change_act']].sort_values('rate_change_act')

# %%
difference_ACT.index = difference_ACT['state']

# %%
difference_ACT[(difference_ACT['rate_change_act'] > 20) | (difference_ACT['rate_change_act'] < -20)]['rate_change_act'].sort_values().plot(kind='barh',figsize=(7,7))
plt.xlabel('Rate Change')
# Out:
# Text(0.5, 0, 'Rate Change')

# %% [markdown]
# For ACT participation from 2017 to 2018, Ohio is the only state with more than 20% increase in testers. Alaska, Illinois and Colorado are the states with a decrease of more than 20% drop in participants.
#
# For SAT participation from 2017 to 2018, Illinois, Colorado and Rhode Island are the only states with more than 20% increase in testers. Florida is the only state with a decrease of more than 10% drop in participants.
#
# To evaluation participation, the box plot, heatmap, and histogram are constrasting. The correlation between the two tests are -.84, which is out of a scale -1 to 1. The extreme disparity between the highest peaks in the ACT and SAT participation rate histogram, top at 100-90% and bottom at 10–0% rates, highlights the divergence between the two test. Furthermore, SAT median participation rate is slightly above the lower limit of the ACT’s first quantile. Since the category is rather an integral measure of how related the two populations of the tests are, it is maybe not enabling a cross-comparison.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %%
# from IPython.display import Image
# Image(filename='../data/Maps.png')

# %%
import shapefile as shp

# %%
sns.set(style='whitegrid', palette='pastel', color_codes=True)
sns.mpl.rc('figure', figsize=(10,6))

# %%
# %matplotlib inline

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
final.describe()
# Out:
#        act2017_participation  act2017_eng  act2017_math  act2017_reading  \
# count              51.000000    51.000000     51.000000        51.000000
# mean               65.254902    20.931373     21.182353        22.013725
# std                32.140842     2.353677      1.981989         2.067271
# min                 8.000000    16.300000     18.000000        18.100000
# 25%                31.000000    19.000000     19.400000        20.450000
# 50%                69.000000    20.700000     20.900000        21.800000
# 75%               100.000000    23.300000     23.100000        24.150000
# max               100.000000    25.500000     25.300000        26.000000
#
#        act2017_science  act2017_composite  sat2017_participation  sat2017_erw  \
# count        51.000000          51.000000              51.000000    51.000000
# mean         21.450980          21.519608              39.803922   569.117647
# ...

# %%
national_average = final['sat2017_total'].mean()
national_average
# Out:
# 1126.0980392156862

# %%
# list of states with total SAT scores above national average in 2017
print('States with an above-average total score against the national average depicts a certain indifference towards this academic test as they all have a low participation rate.')
sat2017_score[sat2017_score['sat2017_total'] > national_average]
# Out:
# States with an above-average total score against the national average depicts a certain indifference towards this academic test as they all have a low participation rate.
#            state  sat2017_participation  sat2017_erw  sat2017_math  \
# 0        Alabama                      5          593           572
# 3       Arkansas                      3          614           594
# 5       Colorado                     11          606           595
# 15          Iowa                      2          641           635
# 16        Kansas                      4          632           628
# 17      Kentucky                      4          631           616
# 18     Louisiana                      4          611           586
# 23     Minnesota                      3          644           651
# 24   Mississippi                      2          634           607
# 25      Missouri                      3          640           631
# ...

# %%
print('Total SAT Scores in 2017 has a bit of a positive right hand skew confirming findings above, which means median is significantly below the mean.')
sat2017_score['sat2017_total'].skew()
# Out:
# Total SAT Scores in 2017 has a bit of a positive right hand skew confirming findings above, which means median is significantly below the mean.
# 0.3109033144632309

# %%
national_average_new = final['sat2018_total'].mean()
national_average_new
# Out:
# 1120.0196078431372

# %%
print('There is lesser states that has an above-average total score against the national average of the SAT Total score in 2018, excluding Colorado and Utah. Massachusetts was added to the list with majority of students ie 80% taking the test.')
sat2018_score[sat2018_score['sat2018_total'] > national_average_new]
# Out:
# There is lesser states that has an above-average total score against the national average of the SAT Total score in 2018, excluding Colorado and Utah. Massachusetts was added to the list with majority of students ie 80% taking the test.
#             state  sat2018_participation  sat2018_erw  sat2018_math  \
# 0         Alabama                      6          595           571
# 2         Arizona                     29          577           572
# 3        Arkansas                      5          592           576
# 15           Iowa                      3          634           631
# 16         Kansas                      4          633           631
# 17       Kentucky                      4          630           618
# 18      Louisiana                      4          615           595
# 21  Massachusetts                     80          562           563
# 23      Minnesota                      4          643           655
# ...

# %%
print('Total SAT Scores in 2018 again has a bit of a positive right hand skew confirming findings above which also means the median is signicantly below the mean.')
sat2018_score['sat2018_total'].skew()
# Out:
# Total SAT Scores in 2018 again has a bit of a positive right hand skew confirming findings above which also means the median is signicantly below the mean.
# 0.4664317156487217

# %%
sns.pairplot(final, 
             x_vars=['act2017_participation', 'act2017_eng', 'act2017_math','act2017_reading', 'act2017_science', 'act2017_composite'],
             y_vars=['act2018_participation', 'act2018_eng','act2018_math', 'act2018_reading', 'act2018_science','act2018_composite'],
             hue='act2018_participation', palette=sns.light_palette("red",len(act2018_score['act2018_participation'])))

# %%
sns.pairplot(final, 
             x_vars=['sat2017_participation', 'sat2017_erw', 'sat2017_math','sat2017_total'],
             y_vars=['sat2018_participation', 'sat2018_erw','sat2018_math', 'sat2018_total'],
             hue='sat2018_participation', palette=sns.light_palette("red",len(sat2018_score['sat2018_participation'])))

# %% [markdown]
# Answers: My view follows as aforemented on the proof of an inverse relationship between participation rate and mean total/composite scores, in that the lower the participation rate, the higher the scores obtained.
# This is apparent from the graphs on the bottom row where the lighter color indicates a lower participation rate on the lower end of the rate range and higher end of the verbal and math ranges.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer: No. It is not normally distributed. Rather, a bimodal distribution is observed.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer: No, it does not hold.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer: Statistical inference between two variables does not reflect the true influence of the relationship or whether there is a third variable that influences the participation rate against the mean total/composite score.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer: To begin, you need to normalise the data. The scoring between the 2 tests differs (ACT maximum score of 36 vs SAT maximum score of 1600) and also the type of questions to assess students in the math category. It would not be very appropriate for modeling.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %% [markdown]
# It is not applicable as you need more data to do a t-test of the sample. Moreover, it would not even be reliable or sufficient.
#
# A hypothesis test, two opposing hypotheses about a population, the null hypothesis and the alternative hypothesis, are compared to see the possibility of any relationship between the two sets. With the Null Hypothesis being that there is no difference between the two groups and my Hypothesis that there is a statistically significant difference in participation rates for the ACT and SAT. The p-value will have to be lower than 0.05, the standard, for the null hypothesis to be rejected since the p- value is below the threshold and assume that these two participation rates are statistically different and that the two tests cannot be compared to each other.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# 1. The legality of students required to take the test as per the state law
#
# 2. The ease of taking the test
#
# 3. The necessary requirement by universities as part of the admission process
#
# 4. The cost of the test
#
# 5. Macro factors that influence the participation rates
#
# As deduced from above, Ohio is the only state with more than 20% increase in testers of ACT participation. Alaska, Illinois and Colorado are the states with a decrease of more than 20% drop in participants.
#
# Taking Ohio in particular, ACT is an overwhelming preferred test for students across districts with a reported 95% having chosen the ACT over the SAT, particularly due to the introduction of free preparatory and information materials by the state of education - (https://www.dispatch.com/news/20170228/ohio-schools-must-now-give-act-or-sat-to-all-juniors)
#
# Taking Illinois for example, the number of graduating students who took the ACT dropped dramatically in 2018 in the transition of the new state's decision to focus more on the SAT. In addition, the University of Chicago announced the non-requirement of SAT or ACT as part of admission process - (https://www.chicagotribune.com/news/breaking/ct-university-chicago-sat-act-20180614-story.html) making the entire legailty a test-optional program - (https://www.businessinsider.sg/more-schools-than-ever-are-turning-away-from-sat-and-act-for-admission-2019-10/)
#
# For SAT participation from 2017 to 2018, Illinois, Colorado and Rhode Island are the only states with more than 20% increase in testers. Florida is the only state with a decrease of more than 10% drop in participants.
#
# Based on a review of state college entrance exam testing policy, it is notable that participation in such tests is influenced by state policy.
#
# Taking the case of Colorado, where the standardised test is part of its high school accountability standards - (http://www.cde.state.co.us/accountability/rtr_webinar_powerpoint_2018), the state of education switched from the ACT to the SAT despite keeping the requirement. The effect was a large increase in the SAT participation coupled with a large drop in the ACT participation rate from 2017 to 2018. Changes in participation rate and changes in average scores with a lower 2018 SAT average and a higher 2018 ACT average. This illustrates outcome of a mandatory test - a large drop in participation of the other test.
#
# Taking Illinois once again, the main driver of growth is probably due to the offering of the test to all public high school juniors that reflects a spike in class of 2018. As a result, SAT in that state spiked from 12,402 in the Class of 2017 to 145,919 in the Class of 2018. ACT usage in the state dropped by more than half, from 134,901 in the Class of 2017 to 62,626 this year - (https://www.collegeboard.org/releases/2018/more-than-2-million-students-in-class-of-2018-took-sat-highest-ever). The expansion into new markets - online
#
# Between the two admission tests, SAT is the preferred test among students in 2018 with approximately 2.1 million takers (accounting the international students too) as compared to 1.91 million takers for the ACT - (https://www.washingtonpost.com/education/2018/10/23/sat-reclaims-title-most-widely-used-college-admission-test/)
#
# Research on the cost of taking the test is another consideration, the cost of test coupled with the cost of registration. With the possibility of retaking the test, the overall total cost might be in the hundreds - (https://www.vox.com/the-goods/2019/3/28/18282453/sat-act-college-admission-testing-cost-price)
#
# In 2018 particularly, there are significant gaps demographically between takers from disenfranchised scoring at or below-average scores stem as compared to students from privileged families - The National Center for Fair and Open Testing FairTest. With a finding that scores are strongly linked to household income -(https://www.nytimes.com/interactive/2017/01/18/upshot/some-colleges-have-more-students-from-the-top-1-percent-than-the-bottom-60.html), despite the opportunity of fee waivers that cover two free SATs, the success rate determined by taking the test more than once is possible with wealthy students -(https://1gyhoq479ufd3yna29x7ubjn-wpengine.netdna-ssl.com/wp-content/uploads/ES-Born_to_win-schooled_to_lose.pdf). Another point is the wealth factor allows students to attend better or reputable schools that provide support and tutors -(https://www.cnbc.com/2019/10/03/rich-students-get-better-sat-scores-heres-why.html)
#
# minnesota and  wisconsin, are the two midwestern states that maintains its spots in the top 5 average scores of the SAT. However, it is not popular test(https://archive.nytimes.com/www.nytimes.com/interactive/2013/08/04/education/edlife/where-the-sat-and-act-dominate.html?_r=0)
# with students prefer the ACT over the SAT. This could be due to high-achieving students who aims for elite or top tier univerisites in midwestern. State to state comparison of average SAT scores could not be accurate due to once again, sampling bias.
#
# There is lagged macro components - socioeconomial factors, adversity, population growth, equality index, racial gaps, legality, possible margins of error, univerisity admission requirements - in the national granularity of the given data. Minority students - (https://reports.collegeboard.org/pdf/2018-total-group-sat-suite-assessments-annual-report.pdf)

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# Conclusion:
#
# An issue with the comparison moving forward is not as disruptive as doing a hypothesis testing but still necessary to address. The heaet map concludes the analysis that there is a negative correlation between participation rates and scores, in that low participation rates in a state is highly correlated to high scores on a test. Considering the macro factors - demographically and the legality mandate to take the test - the connection between the two groups seem to be linked by an unseen third factor. The comparison will then be pivoted on analysing states with a certain threshold - a significant change in participation rates from 2017 to 2018.
#
#
# The ACT and SAT participation distributions are roughly the same with states tend to have a preference over a given test. ACT shows a large group of committed states with participation at 100% which also shows a higher baseline participation statewide.
#
# ACT and SAT scores are inversely correlated with their participation rates. This is likely due to selection bias, as low participation means those who are taking the test might be high achievers, whereas high participation dilutes the quality of performance by takers as reflected by the low scores.
#
# There are strong regional association with preference between ACT and SAT. Progressive states leans towards the SAT, while Midwestern conservative states favours the ACT.
#
# The SAT made significant gains in 2018 relative to the ACT.
#
# Moving forward, it is appropriate to focus on states showing similar positions to 2018.

# %% [markdown]
# Recommendations:
#
# First and foremost, liaising with the respective states of education and retaining the relationship with states implementary a mandatory testing will bring an efficiency and a positive impact to the participation rates.
#
# Fee waivers or subsidies of the total costs of test for low income familities or even target high-achievers from these demograohic: providing impartial information and resources in order to get accepted for higher education.
#
# University admission criteria and the scores current or past students had been accepted on and the composition of students are other aspects to improve the participation rates of a given test as the perceived value to succeed in the test increases. More univerisities are opting for the test-optional program so to reticy the rate of participation, this change of attitude has to be address.
#
# Partnership with test centers can help in strategising state targets.
